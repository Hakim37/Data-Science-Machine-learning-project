# %%
import numpy as np
import pandas as pd
df=pd.read_csv('data.txt')

# %%
df
# Out:
#     mdb001 G CIRC B 535 425 197
# 0    mdb002 G CIRC B 522 280 69
# 1                mdb003 D NORM
# 2                mdb004 D NORM
# 3    mdb005 F CIRC B 477 133 30
# 4    mdb005 F CIRC B 500 168 26
# 5                mdb006 F NORM
# 6                mdb007 G NORM
# 7                mdb008 G NORM
# 8                mdb009 F NORM
# 9    mdb010 F CIRC B 525 425 33
# 10               mdb011 F NORM
# 11   mdb012 F CIRC B 471 458 40
# 12   mdb013 G MISC B 667 365 31
# 13               mdb014 G NORM
# 14   mdb015 G CIRC B 595 864 68
# 15               mdb016 G NORM
# 16   mdb017 G CIRC B 547 573 48
# 17               mdb018 G NORM
# 18   mdb019 G CIRC B 653 477 49
# 19               mdb020 G NORM
# 20   mdb021 G CIRC B 493 125 49
# 21               mdb022 G NORM
# 22   mdb023 G CIRC M 538 681 29
# 23               mdb024 G NORM
# 24   mdb025 F CIRC B 674 443 79
# 25               mdb026 F NORM
# 26               mdb027 F NORM
# 27   mdb028 F CIRC M 338 314 56
# ...
